# %% [markdown]
# # Gpt4all on Google Colab by MyEcoria

# %% [markdown]
# ### Download modified version of GPT4ALL for Google colab

# %%
# !git clone https://github.com/PilouCoin/gpt4all-ui-colab.git myia

# %% [markdown]
# ### Download of the GPT4All model (7b)

# %%
# !cd myia/models/llama_cpp/ && wget https://huggingface.co/ParisNeo/GPT4All/resolve/main/gpt4all-lora-quantized-ggml.bin
# Out:
# /bin/bash: line 0: cd: myia/models/llama_cpp/: No such file or directory

# %% [markdown]
# ### Installing prerequisites for python

# %%
# !cd myia && python -m pip install pip --upgrade && python -m pip install -r requirements.txt

# %% [markdown]
# ### Installation of Localtunnel to be able to access the site from the outside

# %%
# !npm install -g npm && npm install -g localtunnel

# %% [markdown]
# ### Launching the app

# %%
# !cd myia && python app.py
